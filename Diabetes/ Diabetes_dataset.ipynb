# %% [markdown]
# Diabetes Data Analysis and Prediction Using Pandas

# %%
###import panda and numpy

# %%
import pandas as pd
import numpy as np

# %%
## Load dataset

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
#shape and size

# %%
df.shape
# Out:
# (768, 9)

# %%
#inspect the given database

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
## Data cleaning

# %%
(df == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
cols_missing = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# %%
# Replace the 0's with NaN

df[cols_missing] = df[cols_missing].replace(0, np.nan)

# %%
# Replace the NaN with the median values

df.fillna(df.median(),inplace=True)

# %%
df.head(30)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6    148.0           72.0           35.0    125.0  33.6
# 1             1     85.0           66.0           29.0    125.0  26.6
# 2             8    183.0           64.0           29.0    125.0  23.3
# 3             1     89.0           66.0           23.0     94.0  28.1
# 4             0    137.0           40.0           35.0    168.0  43.1
# 5             5    116.0           74.0           29.0    125.0  25.6
# 6             3     78.0           50.0           32.0     88.0  31.0
# 7            10    115.0           72.0           29.0    125.0  35.3
# 8             2    197.0           70.0           45.0    543.0  30.5
# 9             8    125.0           96.0           29.0    125.0  32.3
# 10            4    110.0           92.0           29.0    125.0  37.6
# 11           10    168.0           74.0           29.0    125.0  38.0
# ...

# %%
(df == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
## Lets start data visualizarion

# %%
## Loading seaborn and mathploat lib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Glucose distribution by diabetes status

# %%
sns.boxplot(x='Outcome', y='Glucose', data=df)
plt.title("Glucose Levels vs Diabetes Outcome")
plt.show()

# %%
## Median glucose is higher in diabetics (Outcome = 1) than non-diabetics.

# %%
# BMI distribution by diabetes status

# %%
sns.boxplot(x='Outcome', y='BMI', data=df)
plt.title("BMI vs Diabetes Outcome")
plt.show()

# %%
## Median BMI is higher for diabetics (Outcome = 1) than non-diabetics.

# %%
#Correlation heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of Medical Features")
plt.show()

# %%
## Outcome balance

# %%
df['Outcome'].value_counts(normalize=True)*100
# Out:
# Outcome
# 0    65.104167
# 1    34.895833
# Name: proportion, dtype: float64

# %%
## Histograms / KDE plots to see distribution shapes.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Glucose'], kde=True, bins=30, color='skyblue')
plt.title('Glucose Level Distribution')
plt.xlabel('Glucose')
plt.ylabel('Count')
plt.show()

# %%
# 2. Bivariate Analysis - Feature vs Diabetes Outcome

# %%
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# %%
plt.figure(figsize=(15, 8))

for i, col in enumerate(features, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(
        x='Outcome', 
        y=col, 
        data=df, 
        hue='Outcome',      
        palette='Set2', 
        legend=False
    )
    plt.title(f'{col} by Diabetes Outcome')
    plt.xlabel("Diabetes Outcome (0 = No, 1 = Yes)")
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %%
# Univariate Analysis

# %%
num_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 
            'SkinThickness', 'Insulin', 'BMI', 
            'DiabetesPedigreeFunction', 'Age']

# %%
plt.figure(figsize=(15, 20))

for i, col in enumerate(num_cols, 1):
    plt.subplot(4, 2, i)
    sns.histplot(df[col], kde=True, color='skyblue', bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [raw]
# Conclusion from Univariate Analysis
# From the univariate analysis of the Pima Indians Diabetes Dataset, we can observe the following:
#
# Outcome Distribution
#
# Around 65% of patients are non-diabetic (Outcome = 0), and 35% are diabetic (Outcome = 1).
#
# The dataset is moderately imbalanced but still suitable for analysis without heavy resampling.
#
# Glucose
#
# Diabetic patients tend to have higher glucose levels compared to non-diabetic patients.
#
# The distribution is slightly right-skewed, indicating some patients have extremely high glucose values.
#
# BMI
#
# BMI values are mostly between 25 and 40, suggesting that many patients are overweight or obese, which is a known risk factor for diabetes.
#
# Age
#
# Most patients are in their 20s to 40s, but diabetic cases are more common in older individuals.
#
# Pregnancies
#
# Women with more pregnancies tend to have a slightly higher chance of being diabetic.
#
# Most values are concentrated between 0 and 6 pregnancies.
#
# Insulin & Skin Thickness
#
# These variables have a large number of zero values, indicating missing or unrecorded data that may require preprocessing before modeling.
